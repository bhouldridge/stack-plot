# %% [markdown]
# #Stack Plot Exaple Using Random Numbers

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Create some random data to plot.

# %%
x = range(1,21)
y1 = np.random.rand(20)
y2 = np.random.rand(20)

print(x)
print(y1)
print(y2)
# Out:
# range(1, 21)
# [0.95460341 0.6546579  0.03678944 0.45472654 0.31302584 0.91704323
#  0.80537969 0.20585556 0.88793602 0.45487092 0.47641037 0.03307867
#  0.68777149 0.42563237 0.0013825  0.37919203 0.29142826 0.89717404
#  0.37494547 0.89162057]
# [0.55229571 0.68848391 0.65049305 0.64941292 0.32043005 0.89272008
#  0.00544449 0.43940217 0.55390147 0.86303365 0.60645283 0.62921508
#  0.38735415 0.22455903 0.79016419 0.11272747 0.80878326 0.60489096
#  0.4876476  0.408879  ]

# %%
plt.plot([], [], color='r', label = 'y1')
plt.plot([], [], color='b', label = 'y2')

plt.stackplot(x, y1, y2, colors= ['r', 'b'])
plt.title('Stack Plot Random Numbers')
plt.legend()
plt.show()
